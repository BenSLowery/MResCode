# %%
import numpy as np
from scipy.stats import beta as bt
from scipy.stats import norm
import matplotlib.pyplot as plt
from numpy import genfromtxt
plt.style.use('ggplot')

# %%
# epsilon-greedy
def eps_greedy(t_len, k_len, arms, inits, eps=0.1):
    culm_chosen = []
    
    alpha = [inits[0] for k in range(k_len)]
    beta = [inits[1] for k in range(k_len)]

    for t in range(t_len):
        
        # Calculate mean of bernoulli distribution
        empirical_mean=[alpha[k]/(alpha[k]+beta[k]) for k in range(k_len)]
        
        if np.random.rand() > eps:
            # exploit
            choice = np.argmax(empirical_mean)
        else:
            # explore
            choice = np.random.randint(0,k_len)
        
        # observe reward
        r = np.random.random()<arms[choice]
        
        # update state
        alpha[choice] += r
        beta[choice]+= 1-r
        
        # Append choice (for regret metric)
        culm_chosen.append(choice)
        
    return alpha,beta,culm_chosen

# %%
# Thompson Sampling
def Thompson(t_len, k_len, arms, priors):
    culm_chosen = []
    alpha = [priors[0] for k in range(k_len)]
    beta = [priors[1] for k in range(k_len)]
    for t in range(t_len):
        samples = [np.random.beta(alpha[k],beta[k]) for k in range(k_len)] # Collect samples
        best = np.argmax(samples) # Choose best
        r = np.random.random()<arms[best] # observe r_t (reward and for some reason 'True' counts as the value 1)
        # Update the state of the winning arm 
        alpha[best] += r
        beta[best] += 1-r
        # Append best
        culm_chosen.append(best)
    return alpha,beta,culm_chosen

# Plot posterior arm choices
def plot_res(a,b, t_len):
    x=np.linspace(0,1,1000)
    for  i in range(2):
        y = bt(a[i], b[i])
        plt.plot(x,y.pdf(x),  label=f'Posterior: Arm {i+1}, prob {arms[i]}')
    plt.title(f'T={t_len} rounds')
    plt.xlabel('Prob.')
    plt.legend()
    plt.show()

# %%
# UCB-Bayes
def BayesUCB(t_len, k_len, arms, priors, a_quantile=0.05):
    c=norm.ppf(1-a_quantile/2) # stds. as uppper confidence bound
    alpha = [priors[0] for k in range(k_len)]
    beta = [priors[1] for k in range(k_len)]
    culm_chosen = []
    for t in range(t_len):
        arm_probs = [alpha[k]/(alpha[k]+beta[k])+(c*bt(alpha[k],beta[k]).std()) for k in range(k_len)] # Perform bayes UCB with beta prior
        best = np.argmax(arm_probs) # Choose best
        r = np.random.random()<arms[best] # observe r_t (reward and for some reason 'True' counts as the value 1)
        # Update the state of the winning arm 
        alpha[best] += r
        beta[best] += 1-r
        # Append best
        culm_chosen.append(best)
    return alpha,beta,culm_chosen

# %%
# regret
def get_regret(arms, culm_chosen, t_len):
    # Keep empty list to update
    regret=[]
    # Range over length of T
    for T in range(1,t_len+1):
        # Iterate over arms (i know the best arm goes to 0 but i thought id generalise it anyway)
        armval = []
        for idx, arm in enumerate(arms):
            # use the regret rule from notes, take mean of the indicator choices up to the round T
            armval.append((arms[np.argmax(arms)]-arm)*(np.mean([culm_chosen[i]==idx for i in range(0,T)])))
        # Add arm 1 and arm 2 values (i know this is pointless since the best arm is 0 so only counts for non optimal arm)
        regret.append(armval[0]+armval[1])
    return regret

# To plot regrets
def plot_reg(regrets,names,t_len):
    for idx, regret in enumerate(regrets):
        plt.plot(np.cumsum(regret), label='regret {}'.format(names[idx]))
    plt.plot(np.linspace(1,t_len), np.log(np.linspace(1,t_len)), label='log', color='orange')
    plt.legend()
    plt.title(f'Regret T={t_len}')
    plt.show()

# %%
# Simulation study
# !!!takes a while to run so be warned!!!
np.random.seed(42)
sims=100
eps_greedy_sims = []
thompson_sims = []
bucb_sims = []
t_len=10000
arms = [0.5, 0.55]
prior=[1,1]
for s in range(sims):
    print('Simulation {}:'.format(s))
    alpha_eps,beta_eps,c_eps=eps_greedy(t_len,2,arms, prior)
    regret_eps=get_regret(arms, c_eps, t_len)
    eps_greedy_sims.append(regret_eps) # There definitely exists a more efficient way to do this
    print('epsilon_greedy done')
    
    alpha_thomp,beta_thomp,c_thomp=Thompson(t_len,2,arms, prior)
    regret_thomp=get_regret(arms, c_thomp, t_len)
    thompson_sims.append(regret_thomp) 
    print('thompson done')
    
    alpha_bucb, beta_bucb, c_bucb = BayesUCB(t_len,2,arms,prior)
    regret_bucb=get_regret(arms, c_bucb, t_len)
    bucb_sims.append(regret_bucb)
    print('Bayes-UCB done')
# Out:
# Simulation 0:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 1:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 2:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 3:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 4:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 5:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 6:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 7:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 8:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 9:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 10:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 11:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 12:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 13:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 14:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 15:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 16:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 17:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 18:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 19:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 20:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 21:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 22:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 23:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 24:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 25:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 26:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 27:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 28:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 29:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 30:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 31:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 32:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 33:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 34:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 35:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 36:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 37:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 38:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 39:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 40:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 41:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 42:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 43:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 44:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 45:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 46:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 47:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 48:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 49:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 50:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 51:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 52:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 53:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 54:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 55:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 56:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 57:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 58:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 59:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 60:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 61:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 62:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 63:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 64:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 65:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 66:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 67:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 68:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 69:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 70:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 71:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 72:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 73:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 74:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 75:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 76:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 77:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 78:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 79:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 80:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 81:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 82:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 83:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 84:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 85:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 86:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 87:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 88:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 89:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 90:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 91:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 92:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 93:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 94:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 95:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 96:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 97:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 98:
# epsilon_greedy done
# thompson done
# Bayes-UCB done
# Simulation 99:
# epsilon_greedy done
# thompson done
# Bayes-UCB done

# %%
eps_greedy_avg=np.mean(eps_greedy_sims,axis=0)
thompson_avg=np.mean(thompson_sims,axis=0)
bucb_avg=np.mean(bucb_sims,axis=0)
plot_reg([eps_greedy_avg,thompson_avg,bucb_avg], ['epsilon-greedy', 'Thompson', 'Bayes UCB'],t_len)

# %%
# Plot only first 1000
plot_reg([eps_greedy_avg[1:1000],thompson_avg[1:1000],bucb_avg[1:1000]], ['epsilon-greedy', 'Thompson', 'Bayes UCB'],1000)

# %%
# PLot distribution of culmutative regret at end of each simulation
# Slightly lazy way of doing this
tots_eps=[]
tots_thomp=[]
tots_bucb=[]
for row in eps_greedy_sims:
    tots_eps.append(np.cumsum(row)[-1])
for row in thompson_sims:
    tots_thomp.append(np.cumsum(row)[-1])
for row in bucb_sims:
    tots_bucb.append(np.cumsum(row)[-1])
plt.hist(tots_eps, alpha=0.7, color='red', label='epsilon greedy')
plt.hist(tots_thomp,alpha=0.7, color='blue', label='Thompson')
plt.hist(tots_bucb, alpha=0.7, color='violet', label='Bayes UCB')
plt.title('Total Cumulatative regret histogram')
plt.legend()
plt.show()
